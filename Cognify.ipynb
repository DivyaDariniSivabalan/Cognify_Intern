# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaDariniSivabalan/Cognify_Intern/blob/main/Cognify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LEVEL - 1**

# %% [markdown]
# **TASK - 1**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
u = files.upload()
# Out:
#      <input type="file" id="files-108a41dc-7728-4aa4-82f0-f4cab3192934" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-108a41dc-7728-4aa4-82f0-f4cab3192934">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Dataset .csv")

# %%
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
b = df['Cuisines'].str.split(',').explode().value_counts().head(3)
b
# Out:
# Cuisines
# North Indian    2992
#  Chinese        1880
#  Fast Food      1314
# Name: count, dtype: int64

# %%
plt.pie(b, labels = b.index,autopct='%1.1f%%')
plt.show()

# %%
a = ( b /len(df) ) * 100
print(a)
# Out:
# Cuisines
# North Indian    31.326563
#  Chinese        19.683803
#  Fast Food      13.757722
# Name: count, dtype: float64

# %% [markdown]
# **TASK - 2**

# %%
df['City'].value_counts().idxmax()
# Out:
# 'New Delhi'

# %%
c =df.groupby('City')['Aggregate rating'].mean()
c
# Out:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ��stanbul          4.292857
# Name: Aggregate rating, Length: 141, dtype: float64

# %%
d = c.idxmax()
e = c.max()
print(d,e)
# Out:
# Inner City 4.9

# %% [markdown]
# **TASK - 3**

# %%
plt.hist(df['Price range'])
plt.show()

# %%
f = len(df)
g = df['Price range'].value_counts()
h = g / f * 100
print(h)
# Out:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64

# %% [markdown]
# **TASK - 4**

# %%
i = len(df[df['Has Online delivery']== 'Yes'])
k = (i/f)*100
print(k)
# Out:
# 25.662234321013504

# %%
l = df[df['Has Online delivery']== 'Yes']
m = l['Aggregate rating'].mean()
print(m)
# Out:
# 3.2488372093023257

# %%
p = df[df['Has Online delivery']== 'No']
q = p['Aggregate rating'].mean()
print(q)
# Out:
# 2.465295774647887

# %% [markdown]
# **LEVEL - 2**

# %% [markdown]
# **TASK - 1**

# %%
plt.hist(df['Aggregate rating'], bins = 10)
plt.show()

# %%
df['Aggregate rating'].idxmax()
# Out:
# 3

# %%
df['Votes'].mean()
# Out:
# 156.909747670401

# %% [markdown]
# **TASK - 2**

# %%
r = df.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending = False).head(1)
r
# Out:
# Cuisines
# Italian, Deli    4.9
# Name: Aggregate rating, dtype: float64

# %%
s = r.iloc[0]
s
# Out:
# 4.9

# %%
q = df.loc[df['Aggregate rating'] == s  ]
print(q['Restaurant Name'])
# Out:
# 3                                           Ooma
# 8       Spiral - Sofitel Philippine Plaza Manila
# 10                              Silantro Fil-Mex
# 39                                    Coco Bambu
# 48                            Braseiro da G��vea
#                           ...
# 9484              Restaurant Mosaic @ The Orient
# 9514                            Ministry of Crab
# 9524                                Gaga Manjero
# 9538                                   Starbucks
# 9540                            Draft Gastro Pub
# Name: Restaurant Name, Length: 61, dtype: object

# %% [markdown]
# **TASK - 3**

# %%
import geopandas as gpd
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world.plot(figsize=(15, 10))
gdf.plot(ax=ax, marker='o', color='magenta', markersize=50)
plt.title('Location of the Restaurants')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# <ipython-input-169-90f36d6b1caf>:3: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

X = df[['Latitude', 'Longitude']]

num_clusters = 5

kmeans = KMeans()
df['Cluster'] = kmeans.fit_predict(X)
plt.scatter(df['Longitude'], df['Latitude'], c=df['Cluster'], cmap='rainbow')
plt.title('Restaurant Clusters')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# **TASK - 4**

# %%
res_count=df['Restaurant Name'].value_counts()
t=res_count[res_count > 1].index
t
# Out:
# Index(['Cafe Coffee Day', 'Domino's Pizza', 'Subway', 'Green Chick Chop',
#        'McDonald's', 'Keventers', 'Pizza Hut', 'Giani', 'Baskin Robbins',
#        'Barbeque Nation',
#        ...
#        'Raasta', 'The Pint Room', 'Snacks Point', 'The Dosa King', 'Chokola',
#        'Town Hall', 'Halki Aanch', 'Snack Junction', 'Delhi Biryani Hut',
#        'Beliram Degchiwala'],
#       dtype='object', name='Restaurant Name', length=734)

# %%
df.groupby('Restaurant Name')['Aggregate rating'].mean().sort_values(ascending=False)
# Out:
# Restaurant Name
# Restaurant Mosaic @ The Orient     4.9
# Ministry of Crab                   4.9
# Miann                              4.9
# Shorts Burger and Shine            4.9
# Milse                              4.9
#                                   ...
# Cafe Corner                        0.0
# Pheva Tandooris                    0.0
# Pick & Carry                       0.0
# Cafe Brownie                       0.0
# Famous Parantha and Poori Sabzi    0.0
# Name: Aggregate rating, Length: 7446, dtype: float64

# %%
df.groupby('Restaurant Name')['Votes'].sum().sort_values(ascending=False)
# Out:
# Restaurant Name
# Barbeque Nation              28142
# AB's - Absolute Barbecues    13400
# Toit                         10934
# Big Chill                    10853
# Farzi Cafe                   10098
#                              ...
# Muncheezz                        0
# Swiss Gourmessa                  0
# Dosa and Pizza Corner            0
# Sweets n Treats                  0
# Food Station                     0
# Name: Votes, Length: 7446, dtype: int64

# %% [markdown]
# **LEVEL - 3**

# %% [markdown]
# **TASK - 1**

# %%
df['Rating text'].value_counts()
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
u = df[df['Aggregate rating'] > 2.5]
u['Rating text'].value_counts().idxmax()
# Out:
# 'Average'

# %%
v = df[(df['Aggregate rating'] < 2.5) & ( df['Aggregate rating'] > 0 )]
v['Rating text'].value_counts().idxmax()
# Out:
# 'Poor'

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')

df['Review Length'] = df['Rating text'].apply(lambda text: len(word_tokenize(str(text))))

avg_length = df['Review Length'].mean()
print(f"Average Review Length: {avg_length:.2f} words")

print("\nRelationship between Review Length and Rating:")
print(df.groupby('Aggregate rating')['Review Length'].mean())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Average Review Length: 1.34 words
#
# Relationship between Review Length and Rating:
# Aggregate rating
# 0.0    2.0
# 1.8    1.0
# 1.9    1.0
# 2.0    1.0
# 2.1    1.0
# 2.2    1.0
# 2.3    1.0
# 2.4    1.0
# 2.5    1.0
# 2.6    1.0
# 2.7    1.0
# 2.8    1.0
# 2.9    1.0
# 3.0    1.0
# 3.1    1.0
# 3.2    1.0
# 3.3    1.0
# 3.4    1.0
# 3.5    1.0
# 3.6    1.0
# 3.7    1.0
# 3.8    1.0
# 3.9    1.0
# 4.0    2.0
# 4.1    2.0
# 4.2    2.0
# 4.3    2.0
# 4.4    2.0
# 4.5    1.0
# 4.6    1.0
# 4.7    1.0
# 4.8    1.0
# 4.9    1.0
# Name: Review Length, dtype: float64

# %% [markdown]
# TASK -2

# %%
highest_votes = df[df['Votes'] == df['Votes'].max()]
print(highest_votes[['Restaurant Name', 'Votes']])
# Out:
#     Restaurant Name  Votes
# 728            Toit  10934

# %%
highest_votes = df[df['Votes'] == df['Votes'].min()]
print(highest_votes[['Restaurant Name', 'Votes']])
# Out:
#                  Restaurant Name  Votes
# 69              Cantinho da Gula      0
# 874                The Chaiwalas      0
# 879           Fusion Food Corner      0
# 880                Punjabi Rasoi      0
# 887                Baskin Robbin      0
# ...                          ...    ...
# 9044               6 Packs Momos      0
# 9098                   Cafe' Wow      0
# 9099  Chef's Basket Pop Up Caf��      0
# 9103            The Hangout-Deli      0
# 9111                    Platters      0
#
# [1094 rows x 2 columns]

# %%
z = np.corrcoef(df['Aggregate rating'], df['Votes'])
print(z)
# Out:
# [[1.         0.31369058]
#  [0.31369058 1.        ]]

# %%
sns.scatterplot(x='Aggregate rating', y='Votes', data=df)
plt.show()

# %%
# value is 0.31. So, it is moderately positive corelation

# %% [markdown]
# **TASK - 4**

# %%
x1 = df['Has Online delivery']
y = df['Average Cost for two']
x2 = df['Has Table booking']

# %%
sns.scatterplot(x=x1, y=y , hue = x2)
plt.show()

# %%
sns.scatterplot(x=x2, y=y , hue = x1)
plt.show()

# %%
#Both online delivery and Table booking have negative impact of cost

# %%
df['Price range'].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
w = df[(df['Price range'] == 4)  &  (df['Has Table booking'] == 'Yes')]
v = (w['Has Table booking'].value_counts()/f)*100
print(v)
# Out:
# Has Table booking
# Yes    2.86881
# Name: count, dtype: float64

# %%
w1 = df[(df['Price range'] == 4)  &  (df['Has Online delivery'] == 'Yes')]
v1 = (w1['Has Online delivery'].value_counts()/f)*100
print(v1)
# Out:
# Has Online delivery
# Yes    0.554916
# Name: count, dtype: float64

# %%
#High priced resturant use less of these both servies

# %%
sns.boxplot(x='Has Online delivery' , y = 'Average Cost for two', data=df.loc[df['Average Cost for two']<10000 , :] )
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='Average Cost for two'>

# %%
sns.boxplot(x='Has Table booking' , y = 'Average Cost for two', data=df.loc[df['Average Cost for two']<10000 , :] )
# Out:
# <Axes: xlabel='Has Table booking', ylabel='Average Cost for two'>

# %%
#The option for table booking is predominantly available in restaurants with an average cost ranging from 1000 to 2000.
#The option for online delivery is predominantly available in restaurants with an average cost ranging less than 1000.

# %%
sns.boxplot(x='Has Online delivery' , y = 'Average Cost for two', data=df.loc[df['Average Cost for two']<1000 , :] )
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='Average Cost for two'>

# %%
sns.boxplot(x='Has Table booking' , y = 'Average Cost for two', data=df.loc[df['Average Cost for two']<1000, :] )
plt.ylim(100,1000)
# Out:
# (100.0, 1000.0)

# %%
#The option for table booking is predominantly available in restaurants with an average cost ranging from 750 to 850 .
# The option for online delivery is predominantly available in restaurants with an average cost ranging 400 to 600.
